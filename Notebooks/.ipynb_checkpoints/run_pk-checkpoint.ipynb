# %%
import numpy as np
from time import time
from matplotlib import pyplot as plt
from numba import jit
import classy
plt.rcParams.update({'font.size': 28})

# %%
import sys
sys.path.append('/home/addis/PkBk/Library')
sys.path.append('/home/addis/PkBk/Scripts')
import get_field as gf
import compute_grid_info as cgi
import Pk

# %%
#field things!
path = '../../../data/Quijote/' #path to folder containing quijote files.
N_side = 128
rsd_direction = '' # 'z'

redshift = '/snapdir_004/snap_004'
if redshift[-1] == str(4):
    red_info = 'z=0'
elif redshift[-1] == str(2):
    red_info = 'z=1'
else:
    red_info = 'z=NA'

# %%
# %%time
Nside=128
L=1000
rfft=False
order=2
obs_pos=(500,500,-1e+5)#
grid_info = cgi.compute_survey(Nside,L,rfft,order,obs_pos)
#xi,x_norm,ki,k_mag,MAS,k_f,k_ny
# Out:
# CPU times: user 4.33 s, sys: 112 ms, total: 4.44 s
# Wall time: 4.45 s

# %%
# %%time
iFFT=False
dtype=np.complex64
threads=4
verbose=True
# Out:
# CPU times: user 15 µs, sys: 1 µs, total: 16 µs
# Wall time: 21.7 µs

# %%
# %%time
s=1/2 #units of 2*k_f
k_est = np.arange(grid_info[5],grid_info[6],2*s*grid_info[5]) + s*grid_info[5] #create k bins centers - from k_f to k_ny with steps of s*k_f
binning_info = cgi.pk_compute_bins(k_est,s,grid_info[3],grid_info[5])
#In_bin,N_modes
# Out:
# CPU times: user 1.02 s, sys: 44.9 ms, total: 1.07 s
# Wall time: 1.08 s

# %%
# %%time
realisation = str(10016)
field ='_LOS=Cen'
field_tmp = np.load(path + 'fields_CIC/' + realisation + '_' + red_info + '_' + str(N_side) + field+ '.npy') #load field
# Out:
# 1.5258789e-05
# CPU times: user 8.06 ms, sys: 22.4 ms, total: 30.4 ms
# Wall time: 69.5 ms

# %%
#%%time
t=0
l=0
Pk_ell = Pk.Pk(field_tmp,L,Nside,l,k_est,grid_info,binning_info,t,iFFT,dtype,threads,rfft,verbose)

# %%
plt.loglog(k_est,np.abs(Pk_ell.pk))

# %%
#different dictionary for different types of pk computed 
#pk = {} #'_LOS=Cen'
#pk_500 = {}
#pk_real ={} #''
#pk_pp = {} #'_LOS=PP' # make sure to change obs_pos

# %%
#function to run to calculate bispectrum for different multiplles over realisations...
def pk_realisations(field,pk_dict,ls,ts,z_obs,N_realisations):#add path so choose fields as were
    
    Nside=128
    L=1000
    rfft=False
    order=2
    obs_pos=(500,500,z_obs)#
    grid_info = cgi.compute_survey(Nside,L,rfft,order,obs_pos)
    
    iFFT=False
    dtype=np.complex64
    threads=4
    verbose=True
    
    s=1/2 #units of 2*k_f
    k_est = np.arange(grid_info[4],grid_info[5],2*s*grid_info[4])#create k bins centers - from k_f to k_ny with steps of s*k_f
    binning_info = cgi.pk_compute_bins(k_est,s,grid_info[2],grid_info[4])
    #In_bin,N_modes 
    
    for t in ts:#which LOS
        for l in ls:  #which multipoles to calculate
            key_mono = 'l=%d'%(0)
            key ='l=%d'%(l) +',t=' + str(t)[-1]
            pk_dict[key] = np.zeros((N_realisations,len(k_est)),dtype=np.complex64) #create empty arrays in dict to store bispectra
            pk_dict[key_mono] = np.zeros((N_realisations,len(k_est)),dtype=np.complex64)
            for i in range(N_realisations):
                realisation = str(10000 + i)
                print(realisation)                                            #
                field_tmp = np.load(path + 'fields_CIC/' + realisation + '_' + red_info + '_' + str(N_side) + field+ '.npy') #load field
                j = Pk.Pk(field_tmp,L,Nside,l,k_est,grid_info,binning_info,t,iFFT,dtype,threads,rfft,verbose)
                pk_dict[key][i] = j.pk
                pk_dict[key_mono][i] = j.mono
    return pk_dict

ls= [1]#,2
ts = [0,0.5]

pk_500 = pk_realisations('_LOS=-500',pk_500,ls,ts,obs_pos[2],100)
# Out:
# 10000
# 10001
# 10002
# 10003
# 10004
# 10005
# 10006
# 10007
# 10008
# 10009
# 10010
# 10011
# 10012
# 10013
# 10014
# 10015
# 10016
# 10017
# 10018
# 10019
# 10020
# 10021
# 10022
# 10023
# 10024
# 10025
# 10026
# 10027
# 10028
# 10029
# 10030
# 10031
# 10032
# 10033
# 10034
# 10035
# 10036
# 10037
# 10038
# 10039
# 10040
# 10041
# 10042
# 10043
# 10044
# 10045
# 10046
# 10047
# 10048
# 10049
# 10050
# 10051
# 10052
# 10053
# 10054
# 10055
# 10056
# 10057
# 10058
# 10059
# 10060
# 10061
# 10062
# 10063
# 10064
# 10065
# 10066
# 10067
# 10068
# 10069
# 10070
# 10071
# 10072
# 10073
# 10074
# 10075
# 10076
# 10077
# 10078
# 10079
# 10080
# 10081
# 10082
# 10083
# 10084
# 10085
# 10086
# 10087
# 10088
# 10089
# 10090
# 10091
# 10092
# 10093
# 10094
# 10095
# 10096
# 10097
# 10098
# 10099
# 10000
# Not computing $A_{01}$
# 10001
# Not computing $A_{01}$
# 10002
# Not computing $A_{01}$
# 10003
# Not computing $A_{01}$
# 10004
# Not computing $A_{01}$
# 10005
# Not computing $A_{01}$
# 10006
# Not computing $A_{01}$
# 10007
# Not computing $A_{01}$
# 10008
# Not computing $A_{01}$
# 10009
# Not computing $A_{01}$
# 10010
# Not computing $A_{01}$
# 10011
# Not computing $A_{01}$
# 10012
# Not computing $A_{01}$
# 10013
# Not computing $A_{01}$
# 10014
# Not computing $A_{01}$
# 10015
# Not computing $A_{01}$
# 10016
# Not computing $A_{01}$
# 10017
# Not computing $A_{01}$
# 10018
# Not computing $A_{01}$
# 10019
# Not computing $A_{01}$
# 10020
# Not computing $A_{01}$
# 10021
# Not computing $A_{01}$
# 10022
# Not computing $A_{01}$
# 10023
# Not computing $A_{01}$
# 10024
# Not computing $A_{01}$
# 10025
# Not computing $A_{01}$
# 10026
# Not computing $A_{01}$
# 10027
# Not computing $A_{01}$
# 10028
# Not computing $A_{01}$
# 10029
# Not computing $A_{01}$
# 10030
# Not computing $A_{01}$
# 10031
# Not computing $A_{01}$
# 10032
# Not computing $A_{01}$
# 10033
# Not computing $A_{01}$
# 10034
# Not computing $A_{01}$
# 10035
# Not computing $A_{01}$
# 10036
# Not computing $A_{01}$
# 10037
# Not computing $A_{01}$
# 10038
# Not computing $A_{01}$
# 10039
# Not computing $A_{01}$
# 10040
# Not computing $A_{01}$
# 10041
# Not computing $A_{01}$
# 10042
# Not computing $A_{01}$
# 10043
# Not computing $A_{01}$
# 10044
# Not computing $A_{01}$
# 10045
# Not computing $A_{01}$
# 10046
# Not computing $A_{01}$
# 10047
# Not computing $A_{01}$
# 10048
# Not computing $A_{01}$
# 10049
# Not computing $A_{01}$
# 10050
# Not computing $A_{01}$
# 10051
# Not computing $A_{01}$
# 10052
# Not computing $A_{01}$
# 10053
# Not computing $A_{01}$
# 10054
# Not computing $A_{01}$
# 10055
# Not computing $A_{01}$
# 10056
# Not computing $A_{01}$
# 10057
# Not computing $A_{01}$
# 10058
# Not computing $A_{01}$
# 10059
# Not computing $A_{01}$
# 10060
# Not computing $A_{01}$
# 10061
# Not computing $A_{01}$
# 10062
# Not computing $A_{01}$
# 10063
# Not computing $A_{01}$
# 10064
# Not computing $A_{01}$
# 10065
# Not computing $A_{01}$
# 10066
# Not computing $A_{01}$
# 10067
# Not computing $A_{01}$
# 10068
# Not computing $A_{01}$
# 10069
# Not computing $A_{01}$
# 10070
# Not computing $A_{01}$
# 10071
# Not computing $A_{01}$
# 10072
# Not computing $A_{01}$
# 10073
# Not computing $A_{01}$
# 10074
# Not computing $A_{01}$
# 10075
# Not computing $A_{01}$
# 10076
# Not computing $A_{01}$
# 10077
# Not computing $A_{01}$
# 10078
# Not computing $A_{01}$
# 10079
# Not computing $A_{01}$
# 10080
# Not computing $A_{01}$
# 10081
# Not computing $A_{01}$
# 10082
# Not computing $A_{01}$
# 10083
# Not computing $A_{01}$
# 10084
# Not computing $A_{01}$
# 10085
# Not computing $A_{01}$
# 10086
# Not computing $A_{01}$
# 10087
# Not computing $A_{01}$
# 10088
# Not computing $A_{01}$
# 10089
# Not computing $A_{01}$
# 10090
# Not computing $A_{01}$
# 10091
# Not computing $A_{01}$
# 10092
# Not computing $A_{01}$
# 10093
# Not computing $A_{01}$
# 10094
# Not computing $A_{01}$
# 10095
# Not computing $A_{01}$
# 10096
# Not computing $A_{01}$
# 10097
# Not computing $A_{01}$
# 10098
# Not computing $A_{01}$
# 10099
# Not computing $A_{01}$

# %%
pk= {}
pk['500'] = pk_500

# %%
def avg_err(Pk):
    Pk_avg = {}
    Pk_err = {}
    for i in Pk.keys(): # loop over all keys - to get mean and std for each 
        Pk_avg[i] = np.mean(Pk[i],axis=0)
        Pk_err[i] = np.std(Pk[i],axis=0)/np.sqrt(len(Pk[i])) # standard error
    return Pk_avg,Pk_err

Pk_500_avg,Pk_500_err = avg_err(pk_500)
#Pk0_avg,Pk0_err = avg_err(pk_0)
#Pk_avg_real,Pk_err_real = avg_err(pk_real)
#Pk_avg_pp,Pk_err_pp = avg_err(pk_pp)

# %%
plt.figure(figsize=(20,10))
plt.errorbar(k_est,np.abs(Pk_500_avg['l=1,t=0']),yerr=Pk_500_err['l=1,t=0'],fmt ='o',linestyle='none',alpha=0.8)
plt.errorbar(k_est,3*np.abs(Amn_500_avg['[1 0]']),yerr=3*Amn_500_err['[1 0]'],fmt ='o',linestyle='none',alpha=0.8)
plt.errorbar(k_est,3*np.abs(Amn_pp_avg['[1 0]']),yerr=3*Amn_pp_err['[1 0]'],fmt ='o',linestyle='none',alpha=0.8)
plt.yscale('log')
plt.xscale('log')
plt.grid(ls='--',lw=0.75)

# %%
plt.figure(figsize=(20,10))
#plt.plot(k_est,np.abs(pkmono))

plt.errorbar(k_est,np.abs(Pk_avg['l=1,t=0']),yerr=Pk_err['l=1,t=0'],fmt ='o',linestyle='none',alpha=0.8)
plt.errorbar(k_est,np.abs(Pk0_avg['l=1,t=0']),yerr=Pk0_err['l=1,t=0'],fmt ='o',linestyle='none',alpha=0.8)
#plt.errorbar(k_est,np.abs(Pk_avg_real['l=1,t=0']),yerr=Pk_err_real['l=1,t=0'],alpha=0.8)
#plt.errorbar(k_est,np.abs(Pk_avg_pp['l=1,t=0']),yerr=Pk_err_pp['l=1,t=0'],alpha=0.1)
for i in range(100):
    plt.plot(k_est,np.abs(pk['l=1,t=0'][i].imag),',',alpha=0.5,color='grey')

#plt.plot(ks,np.abs(pk_dipo_dfog_wa(ks,10,0)))
plt.plot(ks,np.abs(dip_dfog(ks,5,0))/1.41)
#plt.plot(ks,np.abs(dip_dfog_fake(ks,sigma,t))/1.41)
#plt.plot(ks,Pk_l1_wa) 

plt.axvline(x = grid_info[4], linestyle='-.', color = 'black')
plt.axvline(x = grid_info[5], linestyle='-.', color = 'black')
plt.xlim(2e-3,1e0)
plt.ylim(1e-2,3e+4)
plt.xlabel('$k\,\,[h/\mathrm{Mpc}]$')
plt.ylabel('$i P_{1}(k)\,\,[\mathrm{Mpc}/h]^3$')

plt.yscale('log')
plt.xscale('log')
plt.grid(ls='--',lw=0.75)
#plt.savefig("P_0_pp_comp.png",bbox_inches='tight')#

# %%
plt.figure(figsize=(20,10))
t=0
sigma= 5
plt.plot(ks,np.abs((dip_dfog(ks,sigma,t)-dip_dfog_fake(ks,sigma,t))/dip_dfog(ks,sigma,t)))
plt.axvline(x = grid_info[4], linestyle='-.', color = 'black')
plt.axvline(x = grid_info[5], linestyle='-.', color = 'black')
plt.yscale('log')
plt.xscale('log')
plt.grid(ls='--',lw=0.75)

# %%
#redshift space multipoles
plt.figure(figsize=(14,10))

plt.errorbar(k_est,np.abs(Pk_avg['l=0'].real),yerr=Pk_err['l=0'],fmt ='x',color='blue')
plt.errorbar(k_est,np.abs(Pk0_avg['l=0'].real),yerr=Pk0_err['l=0'],fmt ='x',color='red')
#plt.errorbar(k_est,np.abs(Pk_avg_pp['l=0'].real),yerr=Pk_err_pp['l=0'],fmt ='x',color='grey')#,linestyle='none'

plt.loglog(ks,Pl0_pp,'-',color='blue')
plt.loglog(ks,Pl0_pp+Pk_l0_wa,'--',color='blue')
plt.plot(ks,pk_mono_dfog(ks,10)+pk_mono_dfog_wa(ks,10,0),'-.')

plt.axvline(x = grid_info[4], linestyle='-.', color = 'black')
plt.axvline(x = grid_info[5], linestyle='-.', color = 'black')
plt.xlim(5e-3,0.5e0)
plt.ylim(3e+3,5e+4)
plt.xlabel('$k\,\,[h/\mathrm{Mpc}]$')
plt.ylabel('$i P_{1}(k)\,\,[\mathrm{Mpc}/h]^3$')

plt.xscale('log')
plt.yscale('log')

plt.grid(ls='--',lw=0.75)
plt.savefig("P_0_pp_comp.png",bbox_inches='tight')#

# %%
#calculate t stuff
t=0
coef = ((1-t)**(2))*(t)**(0)
print(coef)
# Out:
# 1

# %%
#redshift space multipoles
plt.figure(figsize=(14,10))


#plt.loglog(ks,Pl0_pp+Pk_l0_wa,'--',color='blue')
#plt.plot(ks,pk_mono_dfog(ks,10),'-.')



#plt.plot(ks,np.abs(full_dfog(ks,5.22,0)))
#plt.errorbar(k_est,np.abs(Pk_500_avg['l=2,t=0'].real),yerr=Pk_500_err['l=2,t=0'],fmt ='-',color='red')
plt.plot(ks,np.abs(pk_dfog(ks,5.3)))
#plt.plot(ks,np.abs(wa_dfog(ks,5.3,0.5)))

#plt.loglog(ks,Pl2_pp,'--',color='black')
for i in range(100):
    1#plt.loglog(k_est,(np.abs(pk_500['l=2,t=5'][i].real)),'.',alpha=0.2,color='blue')
    1#plt.loglog(k_est,(np.abs(pk_500['l=2,t=0'][i].real)),'.',alpha=0.2,color='red')


plt.axvline(x = grid_info[4], linestyle='-.', color = 'black')
plt.axvline(x = grid_info[5], linestyle='-.', color = 'black')
plt.xlim(6e-3,0.1e0)
plt.ylim(3e+3,3e+4)
plt.xlabel('$k\,\,[h/\mathrm{Mpc}]$')
plt.ylabel('$i P_{1}(k)\,\,[\mathrm{Mpc}/h]^3$')

plt.xscale('log')
plt.yscale('log')

plt.grid(ls='--',lw=0.75)
plt.savefig("P_0_pp_comp.png",bbox_inches='tight')
# Out:
# /opt/jupyterhub/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /opt/jupyterhub/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /opt/jupyterhub/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /opt/jupyterhub/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
print(Pk_500_avg['l=2,t=0'].real)
# Out:
# [ 1.7819701e+04  2.0946023e+04  2.1092684e+04  1.8399736e+04
#   1.6295708e+04  1.2740778e+04  1.0690398e+04  9.2870977e+03
#   8.3940107e+03  7.4266719e+03  6.7314678e+03  5.7745713e+03
#   5.1909541e+03  4.4128491e+03  3.8782812e+03  3.4382886e+03
#   3.0757568e+03  2.7856787e+03  2.4419319e+03  2.1484302e+03
#   1.9582914e+03  1.7773545e+03  1.5542238e+03  1.4076637e+03
#   1.2189304e+03  1.0841707e+03  9.5545215e+02  8.2354071e+02
#   7.3219910e+02  6.3339856e+02  5.1848511e+02  4.4649792e+02
#   3.6495963e+02  3.0368054e+02  2.4286067e+02  1.8249136e+02
#   1.4208798e+02  8.2368515e+01  4.5347866e+01  1.5523072e+00
#  -3.1726957e+01 -7.0839447e+01 -1.0482883e+02 -1.3162056e+02
#  -1.5369106e+02 -1.8143451e+02 -2.0019635e+02 -2.2042522e+02
#  -2.4344656e+02 -2.6091949e+02 -2.7300992e+02 -2.8833054e+02
#  -3.0603714e+02 -3.1955255e+02 -3.3143707e+02 -3.4140652e+02
#  -3.5306528e+02 -3.6614453e+02 -3.7411490e+02 -3.8674268e+02
#  -3.9600482e+02 -4.0977405e+02 -4.1763043e+02]

# %%
#real space
plt.figure(figsize=(12,7))


plt.errorbar(k_est,np.abs(Pk_avg_real['l=0']),yerr=Pk_err_real['l=0'],color='blue')
plt.plot(ks[10:],Pks[10:],'--',color='blue')
plt.plot(k,Pnonlin)
#plt.loglog(k_py,Pk0)
#plt.errorbar(k_est,np.abs(Pk_avg_real['l=2,t=0'].real),yerr=Pk_err_real['l=2,t=0'],color='red')
#plt.plot(ks,Pl2_pp+Pk_l2_wa,'--',color='red')


for i in range(25):
    plt.loglog(k_est,(np.abs(pk_real['l=0'][i].real)),alpha=0.1)


plt.axvline(x = grid_info[4], linestyle='-.', color = 'black')
plt.axvline(x = grid_info[5], linestyle='-.', color = 'black')
plt.xlim(5e-3,0.5e0)
plt.ylim(1e+3,5e+4)
plt.xlabel('$k\,\,[h/\mathrm{Mpc}]$')
plt.ylabel('$i P_{1}(k)\,\,[\mathrm{Mpc}/h]^3$')

plt.xscale('log')
plt.yscale('log')

plt.grid(ls='--',lw=0.75)

# %%
from classy import Class
z= 0
#Start by specifying the cosmology - fiducial quijote...
Omega_b = 0.049#0.05
Omega_m = 0.3175
Omega_l = 0.682
Omega_cdm = Omega_m - Omega_b
h = 0.6711#0.7 #H0/100
A_s = 2.1e-9
n_s = 0.9624
a = 1/(1+z)
H  = 100.0*np.sqrt(Omega_m*(1.0+z)**3+Omega_l)*a #Value of H(z) in km/s/(Mpc/h)

#Create a params dictionary
#Need to specify the max wavenumber
k_max = 10 #UNITS: 1/Mpc

params = {   'output':'mPk',
             'non linear':'halofit',
             'Omega_b':Omega_b,
             'Omega_cdm':Omega_cdm,
             'h':h,
             'A_s':A_s,
             'n_s':n_s,
             'P_k_max_1/Mpc':k_max,
             'z_max_pk':10. #Default value is 10
}

#Initialize the cosmology and compute everything
cosmo = Class()
cosmo.set(params)
cosmo.compute()

#Specify k and z
k = np.logspace(-5, np.log10(k_max), num=1000) #Mpc^-1
#z already specififed

#Call these for the nonlinear and linear matter power spectra
Pnonlin = np.array([cosmo.pk(ki, z) for ki in k])
Plin = np.array([cosmo.pk_lin(ki, z) for ki in k])

#NOTE: You will need to convert these to h/Mpc and (Mpc/h)^3
#to use in the toolkit. To do this you would do:
k /= h
Plin *= h**3
Pnonlin *= h**3

# %%
# %%time
import sys
sys.path.append('/home/addis/Pylians3/library/build/lib.linux-x86_64-3.8')
import Pk_library as PKL
BoxSize = 1000.0 #Mpc/h
axis    = 0
MAS     = 'CIC'
threads = 4
field_tmp = np.load(path + 'fields_CIC/' + realisation + '_' + red_info + '_' + str(N_side) + '.npy')
Pk_py = PKL.Pk(np.array(field_tmp,dtype=np.float32), L, axis, MAS, threads, True)
# Out:
# Computing power spectrum of the field...
# Time to complete loop = 0.12
# Time taken = 0.21 seconds
# CPU times: user 5.57 s, sys: 179 ms, total: 5.75 s
# Wall time: 281 ms

# %%
k_py   = Pk_py.k3D
Pk0     = Pk_py.Pk[:,0] #monopole
Pk2     = Pk_py.Pk[:,1] #quadrupole
Pk4     = Pk_py.Pk[:,2] #hexadecapole

# %%
#pylians comparison
plt.figure(figsize=(12,10))
plt.loglog(k_py,Pk0)
plt.loglog(k_est,np.abs(Pk_avg_real['l=0'].real))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-9779ead61f57> in <module>
#       2 plt.figure(figsize=(12,10))
#       3 plt.loglog(k_py,Pk0)
# ----> 4 plt.loglog(k_est,np.abs(Pk_avg_real['l=0'].real))
#
# NameError: name 'Pk_avg_real' is not defined

# %%
#%%time
t=0.5
import cProfile
cProfile.run('Pk.Pk(field_tmp,L,Nside,l,k,grid_info,binning_info, t,iFFT,dtype,threads,rfft,verbose)')

# %%
#this just changes things from mathematica form to python
from sympy.parsing.mathematica import mathematica  
from sympy import var

# %%
with open('mathematica_output.txt') as file:
    string1 = file.read()
    string1 = string1.replace('\n','').replace('  ','')#.replace('Sqrt[pi]','(np.pi)**(1/2)')
#print(string1.replace(". ", "").replace("\n", "").replace("\\", "").replace("x", "d").replace("kd^2", "(k*d**2)"))#.replace("k", "k[i]"))

#change multiplication and 
python_mathematica = mathematica(string1)
ppp = str(python_mathematica).replace('*I*','*1j*').replace('sqrt(','np.sqrt(').replace('pi','np.pi').replace('e**(','np.exp(').replace('erfunccc','scipy.special.erf((sigma*ks)/np.sqrt(2))').replace('erfunc','scipy.special.erf(sigma*ks)').replace('e**(','np.exp(')
print(ppp)
# Out:
# -3*1j*np.exp(-ks**2*sigma**2)*f*(2*t - 1)*(np.sqrt(np.pi)*np.exp(ks**2*sigma**2)*scipy.special.erf(sigma*ks)*(Pkd*ks*(-4*b1*ks**4*sigma**4 + 15*f + ks**2*sigma**2*(6*b1 - 6*f)) + 12*Pks*(-5*f + ks**2*sigma**2*(-b1 + f))) + 2*ks*sigma*(-Pkd*ks*(15*f + ks**2*sigma**2*(6*b1 + 4*f)) + 4*Pks*(15*f + ks**4*sigma**4*(2*b1 + 2*f) + ks**2*sigma**2*(3*b1 + 7*f))))/(8*d*ks**8*sigma**7)

# %%
# Lambda CDM
from scipy.interpolate import interp1d
from scipy.integrate import quad
from scipy import interpolate
LCDM = Class()
LCDM.compute()
print(LCDM.get_current_derived_parameters)
baLCDM = LCDM.get_background()
print(baLCDM.keys())
f_cl = baLCDM['gr.fac. f']
z_cl = baLCDM['z']
H_cl = baLCDM['H [1/Mpc]'];H = interp1d(z_cl,H_cl*(1/(1+z_cl))/h,kind='cubic') # now in h/Mpc!
f_intp = interp1d(z_cl,f_cl,kind='cubic')#get f #omega_mz = Omega_m *(1+zt)**3 /(Omega_m *(1+zt)**3 + Omega_l)
# calculate d from z then interpolate values? - check with CLASS
def comving_to_redshift():
    def integrand(z): # integrand function to integrate over Hubble parameter
        return 1/(H(z)*(1+z))#Normal Hubble
    sample_size = 10000
    z_sample = np.linspace(0,10,sample_size) # sample points in redshift range
    r_sample = np.zeros(sample_size)
    for i in range(sample_size):
        r_sample[i] = quad(integrand, 0, z_sample[i])[0]  #integrate to get comving distance
    
    dd_dz = interpolate.interp1d((z_sample[1:]+z_sample[:-1])/2,np.diff(r_sample)/np.diff(z_sample))#find numerical derivatives of biases interp1d(z_sample,r_sample,kind='cubic')
    return interp1d(z_sample,r_sample,kind='cubic')#,dd_dz
comoving_dist = comving_to_redshift()#,dd_dz
# Out:
# <built-in method get_current_derived_parameters of classy.Class object at 0x5565c54959c0>
# dict_keys(['z', 'proper time [Gyr]', 'conf. time [Mpc]', 'H [1/Mpc]', 'comov. dist.', 'ang.diam.dist.', 'lum. dist.', 'comov.snd.hrz.', '(.)rho_g', '(.)rho_b', '(.)rho_cdm', '(.)rho_lambda', '(.)rho_ur', '(.)rho_crit', '(.)rho_tot', '(.)p_tot', '(.)p_tot_prime', 'gr.fac. D', 'gr.fac. f'])

# %%
#%%time
z= 0.0
print(z)
#ok so set a comoving distance of observation
d = comoving_dist(z)
if d == 0:
    d=np.sqrt(250**2 + 250**2 + 250**2)
print(d)
#set z ...
def get_class_powerspectrum(kk,zz): #h are needed to convert to 1/Mpc for k then convert pk back to (Mpc/h)^3
    
    return np.array([cosmo.pk_lin(ki, zz) for ki in kk*h])*h**3

def get_pkinfo_z(k,z):
    Plin = get_class_powerspectrum(k,z)
    Pk = interpolate.interp1d(k,Plin)#Plin
    Pk_d = interpolate.interp1d(k,np.gradient(Plin,k))#(k[1:]+k[:-1])/2,np.diff(Plin)/np.diff(k)
    Pk_dd = interpolate.interp1d(k,np.gradient(Pk_d(k),k))
    return Pk,Pk_d,Pk_dd

#so set parameters...
Pk_,Pk_d,Pk_dd = get_pkinfo_z(k,z)


ks = np.geomspace(1e-3,4e-1,100)
f = f_intp(z)

Pks = Pk_(ks)
Pkd= Pk_d(ks)
Pkdd= Pk_dd(ks)


b1 = 1
s=0
t=0
# Out:
# 0.0
# 433.0127018922193

# %%
Pk_l0_wa = f*(Pks*(7*b1*(-25*s - t*(12*t - 12) + 4) + f*(175*s - t*(36*t - 36) - 68)) + ks*(Pkd*(-35*b1*(5*s + t*(4*t - 4)) + f*(175*s - t*(60*t - 60) - 48)) - 2*Pkdd*ks*(7*b1*(t*(2*t - 2) + 1) + f*(t*(6*t - 6) - 5))))/(105*d**2*ks**2)
Pk_l1_wa = -4*f*(3*Pks+ Pkd*ks)*(7*b1 + 3*f)*(2*t - 1)/(35*d*ks)
Pk_l2_wa = 2*f*(-Pks*(2*b1*(70*s + t*(66*t - 66) + 5) + f*(-35*s + t*(108*t - 108) + 40)) + ks*(Pkd*(b1*(70*s + t*(44*t - 44) - 6) + f*(35*s - t*(12*t - 12) - 6)) + Pkdd*ks*(11*b1 + 3*f)*(t*(2*t - 2) + 1)))/(21*d**2*ks**2)


Pl0_pp = b1**2 *Pks+ (2*b1*f*Pks)/3 + (f**2 *Pks)/5
Pl2_pp = (4*b1*f*Pks)/3 + (4*f**2 *Pks)/7

# %%
#these are some multipoles without inverse distance terms
Pk_l0_wa1 = 2*f*(Pks*(-21*b1*(t*(2*t - 2) + 1) - 18*f*t*(t - 1) + f) + ks*(Pkd*(-35*b1*(t*(2*t - 2) + 1) + f*(-t*(30*t - 30) + 11)) + Pkdd*ks*(-7*b1*(t*(2*t - 2) + 1) + f*(-t*(6*t - 6) + 5))))/(105*d**2*ks**2)
Pk_l2_wa1 = 2*f*(-2*Pks*(33*b1*(t*(2*t - 2) + 1) + f*(t*(54*t - 54) + 13)) + ks*(2*Pkd*(22*b1*t*(t - 1) + 11*b1 - 6*f*t*(t - 1) + 4*f) + Pkdd*ks*(11*b1 + 3*f)*(t*(2*t - 2) + 1)))/(21*d**2*ks**2)

# %%
#plt.loglog(ks,Pl0_pp,color='blue')
#plt.loglog(ks,Pl0_pp+Pk_l0_wa,'--',color='blue')
#plt.loglog(ks,Pl0_pp+Pk_l0_wa1,'-.',color='blue')
plt.loglog(ks,Pl2_pp,color='red')
plt.loglog(ks,Pl2_pp+Pk_l2_wa,'--',color='red')
plt.loglog(ks,Pl2_pp+Pk_l2_wa1,'-.',color='red')
#plt.loglog(ks,Pk_l1_wa)

# %%
import scipy

# %%
#all quadrupole
#PP with dfog
def pk_dfog(ks,sigma):
    Pks= Pk_(ks)
    return 5*Pks*np.exp(-ks**2*sigma**2)*(-np.sqrt(np.pi)*np.exp(ks**2*sigma**2)*scipy.special.erf(sigma*ks)*(8*b1**2*ks**6*sigma**6 + 4*b1*ks**4*sigma**4*(-3*b1 + 2*f) - 45*f**2 + 6*f*ks**2*sigma**2*(-6*b1 + f)) - 90*f**2*ks*sigma - 24*f*ks**3*sigma**3*(3*b1 + 2*f) - ks**5*sigma**5*(24*b1**2 + 32*b1*f + 16*f**2))/(32*ks**7*sigma**7)

#include all terms!!
def full_dfog_inv(ks,sigma,t):
    Pks= Pk_(ks)
    Pkd= Pk_d(ks)
    Pkdd= Pk_dd(ks)
    return -5*np.exp(-ks**2*sigma**2)*(-8*Pks*(-8*b1**2*ks**9*sigma**7*(6*d**2 + sigma**2*(4*ks**2*sigma**2 - t**2*(16*ks**2*sigma**2 + 24) + t*(16*ks**2*sigma**2 + 24) + 15)) + 4*b1*f*ks**3*sigma**3*(-16*ks**8*sigma**8 - 16*ks**6*sigma**4*(d**2 + sigma**2*(7 - 5*s)) - 4*ks**4*(9*d**2*sigma**2 + sigma**4*(73 - 70*s)) + 15*ks**2*sigma**2*(24*s - 35) + t**2*(64*ks**8*sigma**8 + 160*ks**6*sigma**6 + 912*ks**4*sigma**4 + 2808*ks**2*sigma**2 + 5400) - t*(64*ks**8*sigma**8 + 160*ks**6*sigma**6 + 912*ks**4*sigma**4 + 2808*ks**2*sigma**2 + 5400) - 450) + np.sqrt(np.pi)*np.exp(ks**2*sigma**2)*scipy.special.erf(sigma*ks)*(4*b1**2*ks**8*sigma**6*(d**2*(-4*ks**2*sigma**2 + 6) + 3*sigma**2*(-2*ks**2*sigma**2 - 8*t**2 + 8*t + 5)) - 2*b1*f*ks**2*sigma**2*(8*d**2*ks**6*sigma**4 + ks**4*(-36*d**2*sigma**2 + sigma**4*(40*s - 22)) + 45*ks**2*sigma**2*(8*s - 5) - t**2*(792*ks**2*sigma**2 - 5400) + t*(792*ks**2*sigma**2 - 5400) - 450) + f**2*(
    return -5*f*(5*s - 2)*(np.sqrt(np.pi)*scipy.special.erf(sigma*ks)*(4*Pks*(9*b1 + 9*f + ks**2*sigma**2*(b1 - f)) + Pkd*ks*(-4*b1*ks**4*sigma**4 - 18*b1 - 9*f + ks**2*sigma**2*(10*b1 + 2*f))) + 2*np.exp(-ks**2*sigma**2)*ks*sigma*(-4*Pks*(9*b1 + 9*f + ks**4*sigma**4*(2*b1 + 2*f) + ks**2*sigma**2*(7*b1 + 5*f)) + Pkd*ks*(18*b1 + 9*f + ks**2*sigma**2*(2*b1 + 4*f))))/(16*d**2*ks**7*sigma**5)

def inv_dfog(ks,sigma):
    Pks= Pk_(ks)
    return 5*Pks*f**2*(2 - 5*s)**2*(np.sqrt(np.pi)*scipy.special.erf(sigma*ks)*(-2*ks**2*sigma**2 + 9) - 2*np.exp(-ks**2*sigma**2)*ks*sigma*(4*ks**2*sigma**2 + 9))/(16*d**2*ks**7*sigma**5)

# %%
#dipole stuff 
#include all terms!!
def dip_dfog(ks,sigma,t):
    Pks= Pk_(ks)
    Pkd= Pk_d(ks)
    return 3*1j*np.exp(-ks**2*sigma**2)*(2*t - 1)*(np.sqrt(np.pi)*np.exp(ks**2*sigma**2)*scipy.special.erf(sigma*ks)*(Pkd*ks*(-8*b1**2*ks**6*sigma**6 + 4*b1*ks**4*sigma**4*(3*b1 - 2*f) + 45*f**2 - 6*f*ks**2*sigma**2*(-6*b1 + f)) - 4*Pks*(4*b1**2*ks**6*sigma**6 + 45*f**2 - 3*f*ks**2*sigma**2*(-6*b1 + f))) + 2*ks*sigma*(-Pkd*ks*(45*f**2 + 12*f*ks**2*sigma**2*(3*b1 + 2*f) + ks**4*sigma**4*(12*b1**2 + 16*b1*f + 8*f**2)) + 4*Pks*(45*f**2 + 2*f*ks**4*sigma**4*(6*b1 + 5*f) + 9*f*ks**2*sigma**2*(2*b1 + 3*f) + 4*ks**6*sigma**6*(b1 + f)**2)))/(32*d*ks**8*sigma**7)

def dip_dfog_fake(ks,sigma,t):
    Pks= Pk_(ks)
    Pkd= Pk_d(ks)
    return -3*1j*np.exp(-ks**2*sigma**2)*f*(2*t - 1)*(np.sqrt(np.pi)*np.exp(ks**2*sigma**2)*scipy.special.erf(sigma*ks)*(Pkd*ks*(-4*b1*ks**4*sigma**4 + 15*f + ks**2*sigma**2*(6*b1 - 6*f)) + 12*Pks*(-5*f + ks**2*sigma**2*(-b1 + f))) + 2*ks*sigma*(-Pkd*ks*(15*f + ks**2*sigma**2*(6*b1 + 4*f)) + 4*Pks*(15*f + ks**4*sigma**4*(2*b1 + 2*f) + ks**2*sigma**2*(3*b1 + 7*f))))/(8*d*ks**8*sigma**7)

# %%
def pk_mono_dfog(ks,sigma):
    Pks = Pk_(ks)
    return Pks*(np.sqrt(np.pi)*scipy.special.erf(sigma*f*ks)*(4*b1*f*ks**2*sigma**2*(b1*f*ks**2*sigma**2 + 1) + 3) + 2*np.exp(-f**2*ks**2*sigma**2)*f*ks*sigma*(-2*f*ks**2*sigma**2*(2*b1 + f) - 3))/(8*f**3*ks**5*sigma**5)

1*f*ks**2*sigma**2*(f**2*ks**2*sigma**2 + 5) + 12*f**4*ks**4*sigma**4 + 90*f**2*ks**2*sigma**2 + 405) + 135)) + Pkdd*ks*(np.sqrt(np.pi)*np.exp(f**2*ks**2*sigma**2)*scipy.special.erf(sigma*f*ks)*f*(2*b1*f*ks**2*sigma**2*(2*f**4*ks**4*sigma**4 - 5*f**2*ks**2*sigma**2 + 6) + 2*f**4*ks**4*sigma**4 - 15*f**2*ks**2*sigma**2 + t**2*(4*b1*f*ks**2*sigma**2*(2*f**4*ks**4*sigma**4 - 5*f**2*ks**2*sigma**2 + 6) + 12*f**4*ks**4*sigma**4 - 54*f**2*ks**2*sigma**2 + 90) - t*(4*b1*f*ks**2*sigma**2*(2*f**4*ks**4*sigma**4 - 5*f**2*ks**2*sigma**2 + 6) + 12*f**4*ks**4*sigma**4 - 54*f**2*ks**2*sigma**2 + 90) + 30) + 2*f**2*ks*sigma*(2*b1*f*ks**2*sigma**2*(f**2*ks**2*sigma**2 - 6) - 5*f**2*ks**2*sigma**2 + t**2*(4*b1*f*ks**2*sigma**2*(f**2*ks**2*sigma**2 - 6) - 6*f**2*ks**2*sigma**2 - 90) + t*(-4*b1*f*ks**2*sigma**2*(f**2*ks**2*sigma**2 - 6) + 6*f**2*ks**2*sigma**2 + 90) - 30)))/f)/(8*d**2*f**5*ks**9*sigma**7)

def pk_dipo_dfog_wa(ks,sigma,t):
    Pks = Pk_(ks)
    Pkd= Pk_d(ks)
    Pkdd= Pk_dd(ks)
    return 3*np.exp(-f**2*ks**2*sigma**2)*(2*t - 1)*(np.sqrt(np.pi)*np.exp(f**2*ks**2*sigma**2)*scipy.special.erf(sigma*f*ks)*(Pkd*ks*(-4*b1*f**3*ks**4*sigma**4 + f*ks**2*sigma**2*(6*b1 - 6*f) + 15) - 12*Pks*(f*ks**2*sigma**2*(b1 - f) + 5)) + 2*f*ks*sigma*(-Pkd*ks*(2*f*ks**2*sigma**2*(3*b1 + 2*f) + 15) + 4*Pks*(2*f**3*ks**4*sigma**4*(b1 + f) + f*ks**2*sigma**2*(3*b1 + 7*f) + 15)))/(8*d*f**5*ks**8*sigma**7)

plt.plot(ks,pk_mono_dfog(ks,10))
plt.plot(ks,pk_quad_dfog(ks,10))

# %%
#redshift space multipoles
plt.figure(figsize=(14,10))
sigma=5.22
t=0

plt.plot(ks,np.abs(dip_dfog(ks,sigma,t)))
plt.plot(ks,np.abs(dip_dfog_fake(ks,sigma,t)))
plt.plot(ks,Pk_l1_wa) 

plt.axvline(x = grid_info[4], linestyle='-.', color = 'black')
plt.axvline(x = grid_info[5], linestyle='-.', color = 'black')
#plt.xlim(5e-3,0.1e0)
#plt.ylim(3e+3,3e+4)
plt.xlabel('$k\,\,[h/\mathrm{Mpc}]$')
plt.ylabel('$i P_{1}(k)\,\,[\mathrm{Mpc}/h]^3$')

plt.xscale('log')
plt.yscale('log')

plt.grid(ls='--',lw=0.75)
#plt.savefig("P_0_pp_comp.png",bbox_inches='tight')#

# %%
plt.figure(figsize=(16,12))
plt.plot(ks,Pl2_pp,'k')
#plt.plot(ks,np.abs(wa_dfog(ks,5.22,0)+wainv_dfog(ks,5.22)+inv_dfog(ks,5.22)))
#plt.plot(ks,np.abs(full_dfog_inv(ks,5.22,1)))
plt.plot(ks,np.abs(wa_dfog(ks,5.22,0)))
plt.plot(ks,np.abs(wa_dfog_fake(ks,5.22,0)))
plt.plot(ks,np.abs(pk_dfog(ks,5.22)+Pk_l2_wa))


#plt.plot(ks,np.abs(Pl2_pp+wainv_dfog(ks,5.22)))
#plt.plot(ks,np.abs(Pl2_pp+inv_dfog(ks,5.22)))





plt.axvline(x = grid_info[4], linestyle='-.', color = 'black')
plt.axvline(x = grid_info[5], linestyle='-.', color = 'black')

plt.ylim(1e+1,1e+5)
plt.xlim(2e-3,5e-1)
plt.yscale('log')
plt.xscale('log')

# %%
plt.figure(figsize=(16,12))
#plt.plot(ks,np.abs(pk_quad_dfog(ks,10)))
plt.plot(ks,Pl2_pp,'k')

plt.plot(ks,np.abs(full_dfog(ks,5.22,0)),'-.')
plt.plot(ks,np.abs(full_dfog1(ks,5.22,0)),'-.')
plt.plot(ks,np.abs(full_dfog_inv(ks,5.22,0)),'-.')
#plt.plot(ks,np.abs(full_dfog1(ks,5.22,0)))
#plt.plot(ks,np.abs(full_dfog2(ks,5.22,0)))

plt.plot(ks,np.abs(pk_quad_dfog(ks,10)))
#plt.plot(ks,np.abs(pk_quad_dfog(ks,10)+pk_quad_dfog_wa(ks,10,0)),'--',color='black')
plt.plot(ks,np.abs(pk_quad_dfog(ks,10)+Pk_l2_wa1),'--')

plt.ylim(1e+1,1e+5)
plt.xlim(2e-3,4e-1)
plt.yscale('log')
plt.xscale('log')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-4a4110ebfa3a> in <module>
#       3 plt.plot(ks,Pl2_pp,'k')
#       4
# ----> 5 plt.plot(ks,np.abs(full_dfog(ks,5.22,0)),'-.')
#       6 plt.plot(ks,np.abs(full_dfog1(ks,5.22,0)),'-.')
#       7 plt.plot(ks,np.abs(full_dfog_inv(ks,5.22,0)),'-.')
#
# NameError: name 'full_dfog' is not defined

# %%
plt.figure(figsize=(12,8))
#plt.plot(ks,pk_mono_dfog(ks,5))
plt.plot(ks,np.abs(pk_mono_dfog(ks,10)))
plt.plot(ks,np.abs(pk_mono_dfog(ks,10)+pk_mono_dfog_wa(ks,10,0)))
plt.plot(ks,np.abs(pk_mono_dfog(ks,10)+Pk_l0_wa1))
#plt.plot(ks,np.abs(pk_quad_dfog(ks,10)+pk_quad_dfog_wa(ks,10,0)),'--')

plt.plot(ks,Pl0_pp)
plt.yscale('log')
plt.xscale('log')
plt.show()

# %%
plt.plot(ks,np.abs(pk_dipo_dfog_wa(ks,10,0)))
plt.plot(ks,Pk_l1_wa)
#plt.yscale('log')
plt.xscale('log')

# %%
plt.figure(figsize=(12,8))
plt.plot(ks,np.abs(pk_mono_dfog_wa(ks,10,0)))
plt.plot(ks,np.abs(Pk_l0_wa1))

plt.xscale('log')
plt.yscale('log')
plt.grid(ls='--',lw=0.75)
